# %%
import numpy as np
import pandas as pd

# %%
# %%bigquery
# SELECT cb.limit_balance, pd.sex, pd.marital_status, pd.age, pi.pay_0, pi.pay_2, pi.pay_3, pi.pay_4, pi.pay_5, pi.pay_6, bi.bill_amt_1,	bi.bill_amt_2,	bi.bill_amt_3,	bi.bill_amt_4,	bi.bill_amt_5,	bi.bill_amt_6, ei.education_level, el.degree, dp.default_payment_next_month
# FROM `dev-rep-final-projects.credit_card_payments.card_limit` as cb
# LEFT JOIN `dev-rep-final-projects.credit_card_payments.personal_data` as pd
# ON cb.card_holder_id = pd.id
# LEFT JOIN `dev-rep-final-projects.credit_card_payments.payment_info` as pi
# ON cb.card_holder_id = pi.id
# LEFT JOIN `dev-rep-final-projects.credit_card_payments.default_payment_data` as dp
# ON cb.card_holder_id = dp.id
# LEFT JOIN `dev-rep-final-projects.credit_card_payments.bill_info` as bi
# ON cb.card_holder_id = bi.id
# LEFT JOIN `dev-rep-final-projects.credit_card_payments.education_info` as ei
# ON cb.card_holder_id = ei.id
# LEFT JOIN `dev-rep-final-projects.credit_card_payments.education_labels` as el
# ON ei.education_level = el.id
# ORDER BY cb.card_holder_id ASC

# %%
pd.options.display.max_columns = 30

# %%
bank_df = pd.read_csv('bank_results.csv', delimiter=',')
bank_df
# Out:
#       limit_balance  sex  marital_status  age  pay_0  pay_2  pay_3  pay_4  \
# 0             50000    1               2   39      0      0      0      0
# 1            110000    2               2   29      0      0      0      0
# 2            270000    1               2   36      0      0      0      2
# 3            130000    1               1   45      0      0      0      0
# 4             50000    1               2   24      0      0      0      0
# ...             ...  ...             ...  ...    ...    ...    ...    ...
# 2960         210000    2               1   39     -1     -1     -1     -1
# 2961         280000    2               1   41      2     -1     -1     -1
# 2962          80000    1               2   28      1     -1     -1     -1
# 2963         200000    1               1   53      1     -1     -1     -2
# 2964          20000    2               2   24     -1     -1     -2     -2
#
#       pay_5  pay_6  pay_amt_1  pay_amt_2  pay_amt_3  pay_amt_4  pay_amt_5  \
# 0         0      0       1800       2000       3000       2000       2000
# 1         0      0       2000       2010       3000       3000       3000
# 2         0      0      10076       4018         14       2051       2000
# 3         0      0       2886       2908       2129       2354       2366
# 4         0      0       1367       1606        692        709        721
# ...     ...    ...        ...        ...        ...        ...        ...
# 2960     -2     -1          0      28428          0          0      12000
# 2961     -2     -1       6859        486          0          0        244
# 2962     -2     -2         47        207          0          0          0
# 2963     -2     -1       2920          0          0          0       6753
# 2964     -2     -2          0          0          0          0          0
#
#       pay_amt_6  bill_amt_1  bill_amt_2  bill_amt_3  bill_amt_4  bill_amt_5  \
# 0          2000       47174       47974       48630       50803       30789
# 1          1000       48088       45980       44231       32489       26354
# 2             0       78630       68921       46512       40335       37165
# 3          2291       58180       59134       61156       62377       63832
# 4           692       42058       35340       22110       19837       19855
# ...         ...         ...         ...         ...         ...         ...
# 2960      33664       44100           0       28428           0           0
# 2961          0         280        6852         486           0           0
# 2962          0           0          47         207           0           0
# 2963          0           0        2920           0           0           0
# 2964          0         379           0           0           0           0
#
#       bill_amt_6  education_level           degree  default_payment_next_month
# 0          15874                1  graduate school                           0
# 1          20221                1  graduate school                           0
# 2          22156                1  graduate school                           0
# 3          65099                1  graduate school                           0
# 4          20151                1  graduate school                           0
# ...          ...              ...              ...                         ...
# 2960       12000                2       university                           0
# 2961         244                1  graduate school                           0
# 2962           0                1  graduate school                           0
# 2963        6753                2       university                           1
# 2964           0                1  graduate school                           0
#
# [2965 rows x 25 columns]

# %%
bank_df.shape
# Out:
# (2965, 25)

# %%
bank_df.isnull().sum()
# Out:
# limit_balance                 0
# sex                           0
# marital_status                0
# age                           0
# pay_0                         0
# pay_2                         0
# pay_3                         0
# pay_4                         0
# pay_5                         0
# pay_6                         0
# pay_amt_1                     0
# pay_amt_2                     0
# pay_amt_3                     0
# pay_amt_4                     0
# pay_amt_5                     0
# pay_amt_6                     0
# bill_amt_1                    0
# bill_amt_2                    0
# bill_amt_3                    0
# bill_amt_4                    0
# bill_amt_5                    0
# bill_amt_6                    0
# education_level               0
# degree                        2
# default_payment_next_month    0
# dtype: int64

# %%
bank_df.default_payment_next_month.value_counts()
# Out:
# 0    2330
# 1     635
# Name: default_payment_next_month, dtype: int64

# %%
bank_df.corr().style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
#     #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col1 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col3 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col10 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col11 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col12 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col13 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col14 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col15 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col16 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col17 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col18 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col19 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col20 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col21 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col2 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col4 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col6 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col8 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col9 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col10 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col11 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col12 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col13 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col14 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col15 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col19 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col22 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row1_col23 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col1 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col4 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col5 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col6 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col7 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col8 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col9 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col10 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_b6ad98c8_498c_11ea_9979_316f53c23584row2_col11 {
#             background-color:  #506bda;

# %%
bank_df.describe()
# Out:
#        limit_balance          sex  marital_status          age        pay_0  \
# count    2965.000000  2965.000000     2965.000000  2965.000000  2965.000000
# mean   163369.308600     1.607757        1.559865    35.193255     0.005059
# std    125030.415472     0.488333        0.522317     9.109439     1.114395
# min     10000.000000     1.000000        0.000000    21.000000    -2.000000
# 25%     50000.000000     1.000000        1.000000    28.000000    -1.000000
# 50%    140000.000000     2.000000        2.000000    34.000000     0.000000
# 75%    230000.000000     2.000000        2.000000    41.000000     0.000000
# max    800000.000000     2.000000        3.000000    69.000000     8.000000
#
#              pay_2        pay_3        pay_4        pay_5        pay_6  \
# count  2965.000000  2965.000000  2965.000000  2965.000000  2965.000000
# mean     -0.122428    -0.141653    -0.185160    -0.225295    -0.254637
# std       1.180784     1.183630     1.178322     1.159003     1.167305
# min      -2.000000    -2.000000    -2.000000    -2.000000    -2.000000
# 25%      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       7.000000     7.000000     8.000000     7.000000     7.000000
#
#            pay_amt_1     pay_amt_2      pay_amt_3      pay_amt_4  \
# count    2965.000000  2.965000e+03    2965.000000    2965.000000
# mean     6348.902867  6.272494e+03    5150.497133    4561.376054
# std     20885.735336  2.887967e+04   14287.079982   13281.499599
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%      1013.000000  9.900000e+02     477.000000     313.000000
# 50%      2234.000000  2.175000e+03    1994.000000    1600.000000
# 75%      5087.000000  5.000000e+03    4500.000000    4000.000000
# max    493358.000000  1.227082e+06  199209.000000  202076.000000
#
#            pay_amt_5      pay_amt_6     bill_amt_1     bill_amt_2  \
# count    2965.000000    2965.000000    2965.000000    2965.000000
# mean     4913.286678    5382.701518   52118.305228   50649.153120
# std     16734.340778   17275.953029   72328.670541   70785.001588
# min         0.000000       0.000000  -11545.000000  -67526.000000
# 25%       323.000000     173.000000    3958.000000    3390.000000
# 50%      1646.000000    1615.000000   24257.000000   23111.000000
# 75%      4021.000000    4081.000000   69852.000000   67827.000000
# max    388071.000000  403500.000000  613860.000000  512650.000000
#
#           bill_amt_3     bill_amt_4     bill_amt_5     bill_amt_6  \
# count    2965.000000    2965.000000    2965.000000    2965.000000
# mean    48239.757504   44089.683305   40956.080607   39773.072513
# std     68145.710745   61907.454056   58271.904751   57303.488981
# min    -25443.000000  -46627.000000  -46627.000000  -73895.000000
# 25%      3302.000000    2582.000000    1958.000000    1430.000000
# 50%     21520.000000   19894.000000   18814.000000   18508.000000
# 75%     63023.000000   58622.000000   53373.000000   52287.000000
# max    578971.000000  488808.000000  441981.000000  436172.000000
#
#        education_level  default_payment_next_month
# count      2965.000000                 2965.000000
# mean          1.849578                    0.214165
# std           0.778184                    0.410311
# min           0.000000                    0.000000
# 25%           1.000000                    0.000000
# 50%           2.000000                    0.000000
# 75%           2.000000                    0.000000
# max           6.000000                    1.000000
